# %% [markdown]
# 1.   read csv file
# 2.   extract x and y, (y is the last column, x is the rest)
# 3.   train_test_split the data
# 4.   Perform standard scaling operation (mean = 0, variance = 1)
# 5.   import RandomForestRegressor from ensemble
# 6.   train the fit (regressor.fit) on x_train, y_train
# 7.   test the metrics against the y_test, y_pred
# 8.   mean_squared_error, root_mean_squared_error, mean_absolute_error
#
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('petrol_consumption.csv')
data.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
x = data.iloc[:,0:4].values
y = data.iloc[:, 4].values
# Out:
# array([541, 524, 561, 414, 410, 457, 344, 467, 464, 498, 580, 471, 525,
#        508, 566, 635, 603, 714, 865, 640, 649, 540, 464, 547, 460, 566,
#        577, 631, 574, 534, 571, 554, 577, 628, 487, 644, 640, 704, 648,
#        968, 587, 699, 632, 591, 782, 510, 610, 524])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=1000, random_state=0)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a2babf547d5a> in <module>
#       2
#       3 regressor = RandomForestRegressor(n_estimators=1000, random_state=0)
# ----> 4 regressor.fit(x_train, y_train)
#       5 y_pred = regressor.predict(x_test)
#
# NameError: name 'x_train' is not defined

# %%
regressor.predict([[9.0,3571,	1976	,0.525]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a5660cd98113> in <module>
# ----> 1 regressor.predict([[9.0,3571,   1976    ,0.525]])
#
# NameError: name 'regressor' is not defined

# %%
from sklearn import metrics

print('Mean absolute error: ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean squared error: ', metrics.mean_squared_error(y_test, y_pred))
print('Root mean squared error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean absolute error:  56.97462499999999
# Mean squared error:  6417.31036625
# Root mean squared error:  80.10811673138996
